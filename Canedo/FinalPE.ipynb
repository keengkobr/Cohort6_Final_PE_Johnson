# %%
user_input = input("Would you like to select Miles Above Mars or Kilometers Above Mars?")
user_number = 0
yards = 0
feet = 0
inches = 0
meters = 0
centimeters = 0
millimeters = 0

if user_input == "Miles Above Mars":
    user_number = float(input("Enter a number"))
    yards = user_number * 1760
    feet = yards * 3  
    inches = feet * 12  
    print(f"Yards: {yards:.2f}\nFeet: {feet:.2f}\nInches: {inches:.2f}")
elif user_input == "Kilometers Above Mars":
    user_number = float(input("Enter a number"))
    meters = user_number * 1000
    centimeters = meters * 100  
    millimeters = centimeters * 10
    print(f"Meters: {meters:.2f}\nCentimeters: {centimeters:.2f}\nMillimeters: {millimeters:.2f}")

# %%
import math
import webbrowser
import pyfiglet
import time

def automatron1(diameter, dough, amount):
    radius = diameter / 2
    area = math.pi * (radius ** 2)
    return (area * amount) / dough

def automatron2(side_length, dough, amount):
    # Area of one equilateral triangle
    area = (math.sqrt(3) / 4) * (side_length ** 2)
    return (area * amount) / dough
    

def automatron3(side_length, dough, amount):
    area = side_length ** 2
    return (area * amount) / dough

def compare():

    efficiency1 = (15, 20 ,2)
    efficiency2 = (20, 20, 1)
    efficiency3 = (18, 18, 1)
    
    auto1_better = pyfiglet.figlet_format("Automatron 1 is the most efficent!")
    auto2_better = pyfiglet.figlet_format("Automatron 2 is the most efficent!")
    auto3_better = pyfiglet.figlet_format("Automatron 3 is the most efficent!")
    tie = pyfiglet.figlet_format("Both deals are a steal!")

    
    if efficiency1 > efficiency2 and efficiency1 > efficiency3:
        print(auto1_better)
    elif efficiency2 > efficiency1 and efficiency2 > efficiency3:
        print(auto2_better)
    elif efficiency3 > efficiency1 and efficiency3 > efficiency2:
        print(auto3_better)
    else:
        print(tie)



compare()

# %%
import numpy

fuel_by_mass = []

with open("FinalPE.txt", "r") as input:
    for line in input:
        mass = float(line.strip())
        fuel_req = round(mass / 12) - 2
        fuel_by_mass.append(fuel_req)

print(numpy.sum(fuel_by_mass))
